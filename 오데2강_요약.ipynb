# %% [markdown]
# <a href="https://colab.research.google.com/github/vicavica/Basics-of-Python-Programming---OpenSource-based-data-analysis_Incomplete/blob/main/%EC%98%A4%EB%8D%B02%EA%B0%95_%EC%9A%94%EC%95%BD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = [10, 20, 30, 40, 50, 60, 70]
list1 = numbers[ : : 2 ]
print(list1)
list2 = numbers[ : : -1]
print(list2)
# Out:
# [10, 30, 50, 70]
# [70, 60, 50, 40, 30, 20, 10]

# %%
[표현식 for 변수 in 반복가능한 객체
[표현식 for 변수 in 반복가능한 객체 if 조건]

# %%
{키 : 표현식 for 변수 in 반복가능 객체}
{키 : 표현식 for 키변수, 값변수 in 딕셔너리.items()}

# %%
c스타일
"형식 지정자를 포함한 문자열" % (변수 리스트)
"문자열 {위치 또는 이름}".format(인자)

# %%
f"문자열 {표현}"

# %%
with open("output.txt", "w") as file:
    file.write("Hello, world!\n ")
