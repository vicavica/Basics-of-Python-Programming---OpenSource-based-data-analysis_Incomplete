# %% [markdown]
# <a href="https://colab.research.google.com/github/vicavica/Basics-of-Python-Programming---OpenSource-based-data-analysis_Incomplete/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D%EA%B8%B0%EC%B4%88_4%EA%B0%95_%EC%8B%A4%EC%8A%B5(%EC%9B%90%EB%B3%B8)_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 4강 2절

# %%
3.1415921
# Out:
# 3.1415921

# %%
"computer"
# Out:
# 'computer'

# %%
"Hello World!"
# Out:
# 'Hello World!'

# %%
(7 + 15) * 2
# Out:
# 44

# %%
2 ** 10 * 5
# Out:
# 5120

# %%
"computer" + "science"
# Out:
# 'computerscience'

# %%
"computer" * 2
# Out:
# 'computercomputer'

# %%
print(2 * 7)
# Out:
# 14

# %%
"Hello World!"
"Python is Fun"
# Out:
# 'Python is Fun'

# %%
print("Hello World!")
print("Python is Fun")
# Out:
# Hello World!
# Python is Fun

# %%
print("Hello World!")
    print("Python is Fun")
# Out:
#   File "/tmp/ipython-input-665160181.py", line 2
#     print("Python is Fun")
#     ^
# IndentationError: unexpected indent

# %%
# 학점 계산
print((4.5 * 2 + 4.0 * 3) / 2)
# Out:
# 10.5

# %%
class = 10
# Out:
#   File "/tmp/ipython-input-3305041997.py", line 1
#     class = 10
#           ^
# SyntaxError: invalid syntax

# %%
_v = 10

# %%
#반지름, 높이 값 할당
rad = 40
hei = 10

#부피 출력
print(1/3 * 3.14 * rad **2 * hei)
#겉넓이 출력
print(3.14 * rad ** 2 + 3.14 * rad * hei)
# Out:
# 16746.666666666664
# 6280.0

# %% [markdown]
# # 4강 3절

# %%
5 / 2
# Out:
# 2.5

# %%
5 // 2
# Out:
# 2

# %%
25 % 7
# Out:
# 4

# %%
8.4 % 0.9
# Out:
# 0.30000000000000016

# %%
number = 10
number % 2
# Out:
# 0

# %%
#내장함수builtinfunction
print(max(2, 3, 4))
print(min(2, 3, 4))
print(round(3.14))
print(abs(-3))
print(pow(2, 3))
# Out:
# 4
# 2
# 3
# 3
# 8

# %% [markdown]
# ## 별 삼각형 출력하기

# %%
print("   *")
print("  ***")
print(" *****")
print("*******")
# Out:
#    *
#   ***
#  *****
# *******

# %%
input()
# Out:
# 30
# '30'

# %%
rad = input()
# Out:
# 30

# %%
rad = input("반지름의 값을 입력하세요: ")
# Out:
# 반지름의 값을 입력하세요: 30

# %% [markdown]
# ## 원뿔의 부피&겉넓이 계산 프로그램 5

# %%
# 원뿔 부피 및 겉넓이 계산 프로그램
rad = 10
hei = 24
sla = pow(rad ** 2 + hei ** 2, 0.5)
#부피 & 겉넓이 출력
print(1 / 3 * 3.14 * rad ** 2 * hei )
print(3.14 * rad ** 2 + 3.14 * rad * sla)
