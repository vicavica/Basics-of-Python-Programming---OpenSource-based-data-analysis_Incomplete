# %% [markdown]
# <a href="https://colab.research.google.com/github/vicavica/Basics-of-Python-Programming---OpenSource-based-data-analysis_Incomplete/blob/main/chap3test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **a는 수강 학점이고 수강학점을 출력하는 코드 **

# %%
a=10
print(a)
# Out:
# 10

# %%
2 ** 10 * 2
# Out:
# 2048
